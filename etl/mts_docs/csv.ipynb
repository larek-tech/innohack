# %%
import pandas as pd
import os

# %%
pages = [
    pd.read_csv("tables/7_0.csv"),
    pd.read_csv("tables/7_1.csv"),
    pd.read_csv("tables/7_2.csv"),
]

# %%
pages[0]
# Out:
#                                             0  \
# 0                                         NaN
# 1                                         NaN
# 2                                 Организация
# 3                                         NaN
# 4  Идентификационный номер\nналогоплательщика
# 5              Вид экономической деятельности
# 6              Организационно-правовая форма/
# 7                         форма собственности
# 8                           Единица измерения
# 9                                       Адрес
#
#                                                    1  \
# 0                                                NaN
# 1                                                NaN
# 2                     Публичное акционерное общество
# 3                            «Мобильные ТелеСистемы»
# 4                                                NaN
# 5  Деятельность в области связи на базе беспровод...
# 6  Публичное акционерное общество/ Совместная час...
# ...
